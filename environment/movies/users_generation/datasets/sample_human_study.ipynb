# %%
import pandas as pd

df = pd.read_csv("./user_features_sampled_genres_600.csv")

# %%
s = df.sample(4, random_state=42)

# %%
s
# Out:
#      Unnamed: 0            name gender
# 110         110       Lily Chen      F  \
# 419         419    Ethan Taylor      M
# 565         565    Samuel Gomez      M
# 77           77  James Thompson      M
#
#                                            description  age            job
# 110  an event planner and loves to play radio-contr...   35  Event Planner  \
# 419  a student and has a passion for surfing. He lo...   18        student
# 565  a student who loves chemistry and watch movies...   24        student
# 77   a clown and an avid Orienteering enthusiast. H...   33          Clown
#
#                               hobby
# 110  Radio-controlled model playing  \
# 419                         Surfing
# 565                       Chemistry
# 77                     Orienteering
#
#                                           genres_liked
# 110  ['science fiction', 'drama', 'comedy', 'advent...  \
# 419             ['drama', 'crime', 'horror', 'action']
# ...

# %%
s["description"].iloc[3]
# Out:
# 'a clown and an avid Orienteering enthusiast. He has been participating in Orienteering competitions since he was in high school and it has become one of his favorite hobbies. He works as a clown, but his real passion lies in exploring new places and pushing his physical limits. When it comes to movies, James is a fan of adventure, thriller, documentary and science fiction movies. He loves the adrenaline-pumping action and the thought-provoking themes that these genres have to offer. He is also a big fan of science fiction movies, as they allow him to explore new worlds and imagine what could be. However, James is not a fan of fantasy or action movies. He finds them too predictable and lacking in realism, and prefers to spend his time on movies that are more grounded in reality.'

# %%
movies = pd.read_json("../../datasets/movielens_latest-small.json").T

# %%
movies.sample(20)
# Out:
#         adult    budget                                             genres
# 25890   False         0                     [{'id': 35, 'name': 'Comedy'}]  \
# 42196   False   1000000  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 10414   False  10000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 16156   False         0                     [{'id': 35, 'name': 'Comedy'}]
# 27586   False  10000000  [{'id': 10402, 'name': 'Music'}, {'id': 18, 'n...
# 15261   False         0                     [{'id': 35, 'name': 'Comedy'}]
# 2649    False  50000000  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 46119   False         0                      [{'id': 18, 'name': 'Drama'}]
# 10428   False  20000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 9732    False         0  [{'id': 10751, 'name': 'Family'}, {'id': 12, '...
# 20678   False         0  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# ...

# %%
# 2 positive film for Lily Chen
# 157336 interstellar
# 13 Forrest Gump
# 1 negative film for Lily Chen
# 274 The Silence of the Lambs
# Now watching: 


# 2 positive for Ethan Taylor
# 245891 John Wick
# 694 The Shining
# 1 negative for Ethan Taylor
# 62 /2001: A Space Odyssey

# 2 positive for Samuel
# 453 A beautiful mind
# 27205 Inception
# 1 negative for Samuel
# 335984 Blade Runner 2049

# 2 positive for James Thompson
# 85 Raiders of the Lost Ark
# 286217 The Martian 
# 1 negative for James Thompson
# 91314  Transformers



# Movies to watch id: 272, 601, 9486, 8587

# %%
movies[movies["id"] == 91314]
# Out:
#        adult     budget                                             genres
# 91314  False  210000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...  \
#
#           id    imdb_id original_language                   original_title
# 91314  91314  tt2109248                en  Transformers: Age of Extinction  \
#
#                                                 overview popularity
# 91314  As humanity picks up the pieces, following the...    167.662  \
#
#       release_date     revenue runtime                            title
# 91314   2014-06-25  1104054072     165  Transformers: Age of Extinction  \
#
#       vote_average vote_count
# 91314        5.918       7425  \
#
#                                                   actors
# 91314  [{'gender': 2, 'id': 13240, 'name': 'Mark Wahl...  \
#
#                                       overview_embedding     director
# 91314  [-0.03978257626295, -0.05509585514664601, 0.01...  Michael Bay
